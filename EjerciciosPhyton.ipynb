# %% [markdown]
# <a href="https://colab.research.google.com/github/valenmontechi/Big-Data/blob/main/EjerciciosPhyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ejercicio 1
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv"

d_hd = pd.read_csv(url)

# %%
#ejercicio 2
print(d_hd.head())
print(d_hd.tail())
# Out:
#    age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0   63    male           1                     145                233
# 1   67    male           4                     160                286
# 2   67    male           4                     120                229
# 3   37    male           3                     130                250
# 4   41  female           2                     130                204
#
#    fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  oldpeak  \
# 0                    1                2             150            0      2.3
# 1                    0                2             108            1      1.5
# 2                    0                2             129            1      2.6
# 3                    0                0             187            0      3.5
# 4                    0                2             172            0      1.4
#
#    slope  num_vessels_flour  thal  heart_disease_severity  exter_angina  \
# ...

# %%
#ejercicio 3
d_hd[['age', 'has_heart_disease']]
# Out:
#      age has_heart_disease
# 0     63                no
# 1     67               yes
# 2     67               yes
# 3     37                no
# 4     41                no
# ..   ...               ...
# 298   45               yes
# 299   68               yes
# 300   57               yes
# 301   57               yes
# 302   38                no
#
# [303 rows x 2 columns]

# %%
#ejercicio 4
d_hd[d_hd['serum_cholestoral'] > 250]
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 1     67    male           4                     160                286
# 6     62  female           4                     140                268
# 7     57  female           4                     120                354
# 8     63    male           4                     130                254
# 11    56  female           2                     140                294
# ..   ...     ...         ...                     ...                ...
# 280   57    male           4                     110                335
# 281   47    male           3                     130                253
# 285   58    male           4                     114                318
# 291   55  female           2                     132                342
# 298   45    male           1                     110                264
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# ...

# %%
#ejercicio 5 (no encontre libreria con la función status())
d_hd.isnull().sum()
# Out:
# age                       0
# gender                    0
# chest_pain                0
# resting_blood_pressure    0
# serum_cholestoral         0
# fasting_blood_sugar       0
# resting_electro           0
# max_heart_rate            0
# exer_angina               0
# oldpeak                   0
# slope                     0
# num_vessels_flour         4
# thal                      2
# heart_disease_severity    0
# exter_angina              0
# has_heart_disease         0
# dtype: int64

# %%
#ejercicio 6
d_hd['thal'] = d_hd['thal'].fillna(999)

# %%
#chequeo
d_hd['thal'].isnull().sum()
# Out:
# np.int64(0)

# %%
#ejercicio 7
d_hd[(d_hd['serum_cholestoral'] > 250) & (d_hd['age'] > 60)]
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 1     67    male           4                     160                286
# 6     62  female           4                     140                268
# 8     63    male           4                     130                254
# 32    64    male           3                     140                335
# 42    71  female           2                     160                302
# 44    61  female           4                     130                330
# 48    65  female           3                     140                417
# 70    65  female           3                     155                269
# 71    67    male           4                     125                254
# 72    62    male           4                     120                267
# 75    65  female           3                     160                360
# 83    68    male           3                     180                274
# ...

# %%
#ejercicio 8
d_hd['slope'].replace({1: 'ascendente', 2: 'descendente'})
# Out:
# 0                3
# 1      descendente
# 2      descendente
# 3                3
# 4       ascendente
#           ...
# 298    descendente
# 299    descendente
# 300    descendente
# 301    descendente
# 302     ascendente
# Name: slope, Length: 303, dtype: object

# %%
#ejercicio 9
d_hd['is_healthy'] = d_hd['heart_disease_severity'] == 0

d_hd
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0     63    male           1                     145                233
# 1     67    male           4                     160                286
# 2     67    male           4                     120                229
# 3     37    male           3                     130                250
# 4     41  female           2                     130                204
# ..   ...     ...         ...                     ...                ...
# 298   45    male           1                     110                264
# 299   68    male           4                     144                193
# 300   57    male           4                     130                131
# 301   57  female           2                     130                236
# 302   38    male           3                     138                175
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# ...

# %%
#ejercicio 10
d_hd_clean = d_hd.copy()

# %%
d_hd_clean = d_hd_clean.dropna()

# %%
d_hd_clean.isnull().sum()
# Out:
# age                       0
# gender                    0
# chest_pain                0
# resting_blood_pressure    0
# serum_cholestoral         0
# fasting_blood_sugar       0
# resting_electro           0
# max_heart_rate            0
# exer_angina               0
# oldpeak                   0
# slope                     0
# num_vessels_flour         0
# thal                      0
# heart_disease_severity    0
# exter_angina              0
# has_heart_disease         0
# is_healthy                0
# dtype: int64
